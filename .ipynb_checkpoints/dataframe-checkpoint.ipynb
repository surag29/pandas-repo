# %% [markdown]
# CREATING DATAFRAME

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

# %%
 df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

# %%
df2 =  pd.DataFrame(data_list)

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
columns = ['name','age','city','salary']
df2 =  pd.DataFrame(data_list,columns = columns)

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and Indexing of Columns

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[['name','city']]
# Out:
#     name      city
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# creating new column

# %%
df2['designation'] = ['hr','it','da','ds']

# %%
df2
# Out:
#     name  age      city  salary designation
# 0   John   28  New York   65000          hr
# 1   Anna   34     Paris   70000          it
# 2  Peter   29    Berlin   62000          da
# 3  Linda   42    London   85000          ds

# %% [markdown]
# removing  column

# %%
df2.drop('designation', axis= 1,inplace=True)

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# SELECTING ROWS

# %%
df2.loc[0]
# Out:
# name          John
# age             28
# city      New York
# salary       65000
# Name: 0, dtype: object

# %%
df2.iloc[0]
# Out:
# name          John
# age             28
# city      New York
# salary       65000
# Name: 0, dtype: object

# %%
df2.iloc[[0,1]]
# Out:
#    name  age      city  salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.iloc[[0,1]][['city','salary']]
# Out:
#        city  salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.iloc[[2,3]][['name','age']]
# Out:
#     name  age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# CONDITIONAL SELECTION

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# i want people of age greater then 30

# %%
df2[df2['age'] > 30 ]
# Out:
#     name  age    city  salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %% [markdown]
# i want people of age greater then 30 and living in paris

# %%
df2[(df2['age'] > 30) & (df2['city'] == 'Paris') ]
# Out:
#    name  age   city  salary
# 1  Anna   34  Paris   70000
